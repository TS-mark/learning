# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier,plot_tree

# %%
n_classes = 3
plot_colors = "ryb"
plot_step = 0.02

iris = load_iris()

# %%
type(iris)
# Out:
# sklearn.utils.Bunch

# %%
for pairidx, pair in enumerate([[0,1],[0,2],[0,3],[1,2],[1,3],[2,3]]):
    x = iris.data[:, pair]
    y = iris.target
    
    # train
    clf = DecisionTreeClassifier().fit(x, y)

    plt.subplot(2, 3, pairidx + 1)

    x_min, x_max = x[:, 0].min() - 1, x[:, 0].max() + 1
    y_min, y_max = x[:, 1].min() - 1, x[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, plot_step),
                          np.arange(y_min, y_max, plot_step))
    plt.tight_layout(h_pad=0.5, w_pad=0.5, pad=2.5)

    z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    z = z.reshape(xx.shape)
    cs = plt.contourf(xx, yy, z, camp=plt.cm.RdYlBu)

    plt.ylabel(iris.feature_names[pair[0]])
    plt.ylabel(iris.feature_names[pair[1]])

    #plot the training points
    for i, color in zip(range(n_classes), plot_colors):
        idx = np.where(y == i)
        plt.scatter(x[idx, 0], x[idx,1], c=color, label=iris.target_names[i],
                   cmap=plt.cm.RdYlBu, edgecolor='black', s=15)

plt.suptitle("Decision surface of a decision tree using paired features")
plt.legend(loc='lower right', borderpad = 0, handletextpad=0)
plt.axis("tight")

plt.figure(figsize=(30, 30))
clf = DecisionTreeClassifier().fit(iris.data, iris.target)
plot_tree(clf, filled=True)
plt.show()
# Out:
# c:\users\44386\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:18: UserWarning: The following kwargs were not used by contour: 'camp'
# Text(20.75, 0.5, 'sepal length (cm)')
# Text(20.75, 0.5, 'sepal width (cm)')
# c:\users\44386\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:18: UserWarning: The following kwargs were not used by contour: 'camp'
# Text(149.27083333333334, 0.5, 'sepal length (cm)')
# Text(149.27083333333334, 0.5, 'petal length (cm)')
# c:\users\44386\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:18: UserWarning: The following kwargs were not used by contour: 'camp'
# Text(280.50000000000006, 0.5, 'sepal length (cm)')
# Text(280.50000000000006, 0.5, 'petal width (cm)')
# c:\users\44386\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:18: UserWarning: The following kwargs were not used by contour: 'camp'
# Text(25.5, 0.5, 'sepal width (cm)')
# Text(25.5, 0.5, 'petal length (cm)')
# c:\users\44386\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:18: UserWarning: The following kwargs were not used by contour: 'camp'
# Text(148.12500000000003, 0.5, 'sepal width (cm)')
# Text(148.12500000000003, 0.5, 'petal width (cm)')
# c:\users\44386\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:18: UserWarning: The following kwargs were not used by contour: 'camp'
# Text(278.37500000000006, 0.5, 'petal length (cm)')
# Text(278.37500000000006, 0.5, 'petal width (cm)')
# Text(0.5, 0.98, 'Decision surface of a decision tree using paired features')
# (0.0, 7.88, -0.9, 3.4800000000000044)
# [Text(837.0, 1494.8999999999999, 'X[3] <= 0.8\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(708.2307692307693, 1223.1, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(965.7692307692308, 1223.1, 'X[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(515.0769230769231, 951.3, 'X[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(257.53846153846155, 679.4999999999999, 'X[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(128.76923076923077, 407.6999999999998, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(386.3076923076923, 407.6999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(772.6153846153846, 679.4999999999999, 'X[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(643.8461538461538, 407.6999999999998, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(901.3846153846155, 407.6999999999998, 'X[2] <= 5.45\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(772.6153846153846, 135.89999999999986, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(1030.1538461538462, 135.89999999999986, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(1416.4615384615386, 951.3, 'X[2] <= 4.85\ngini = 0.043\nsamples = 46\nvalue = [0, 1, 45]'),
#  Text(1287.6923076923076, 679.4999999999999, 'X[0] <= 5.95\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(1158.923076923077, 407.6999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(1416.4615384615386, 407.6999999999998, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(1545.2307692307693, 679.4999999999999, 'gini = 0.0\nsamples = 43\nvalue = [0, 0, 43]')]

# %%
for pairidx, pair in enumerate([[0,1],[0,2],[0,3],[1,2],[1,3],[2,3]]):
    print(pairidx, "aaaaa", pair)
# Out:
# 0 aaaaa [0, 1]
# 1 aaaaa [0, 2]
# 2 aaaaa [0, 3]
# 3 aaaaa [1, 2]
# 4 aaaaa [1, 3]
# 5 aaaaa [2, 3]
