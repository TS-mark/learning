# %%
from typing import Any
import torch
from torchvision import models, transforms
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
class BaseTransform():
    def __init__(self, resize, mean, std):
        self.base_transform = transforms.Compose([
            transforms.Resize(resize),
            transforms.CenterCrop(resize),
            transforms.ToTensor(),
            transforms.Normalize(mean, std)
        ])
    
    def __call__(self, img):
        return self.base_transform(img)

# %%
# 确认图像预处理结果

#1. 读取图片
image_file_path = r"C:\Users\mark\Pictures\00000329.jpg"
img = Image.open(image_file_path)

plt.imshow(img)
plt.show()

#3. 显示图片
resize = 224
mean = (0.15, 0.16, 0.16)
std = (0.229, 0.224, 0.225)
transform = BaseTransform(resize, mean, std)

img_transformed = transform(img)

#(3,224,224) -> (224,224,3)
img_transformed = img_transformed.numpy().transpose((1,2,0))
# 截断
img_transformed = np.clip(img_transformed,0,1)
plt.imshow(img_transformed)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
img_transformed
# Out:
# array([[[-1.2274169 , -0.582633  ,  0.40906325],
#         [-1.2274169 , -0.582633  ,  0.40906325],
#         [-1.2102921 , -0.565126  ,  0.42649257],
#         ...,
#         [-1.0561693 , -0.44257697,  0.42649257],
#         [-1.0390445 , -0.40756297,  0.49620935],
#         [-1.0561693 , -0.39005598,  0.5310677 ]],
#
#        [[-1.2274169 , -0.565126  ,  0.42649257],
#         [-1.2274169 , -0.565126  ,  0.42649257],
#         [-1.2274169 , -0.582633  ,  0.40906325],
#         ...,
#         [-1.1075436 , -0.512605  ,  0.35677567],
#         [-1.073294  , -0.42507   ,  0.46135095],
#         [-1.0390445 , -0.37254897,  0.56592613]],
#
#        [[-1.2274169 , -0.547619  ,  0.42649257],
#         [-1.2445416 , -0.565126  ,  0.40906325],
#         [-1.2445416 , -0.565126  ,  0.40906325],
#         ...,
#         [-1.1246684 , -0.565126  ,  0.19991292],
#         [-1.073294  , -0.460084  ,  0.39163405],
#         [-1.0390445 , -0.37254897,  0.51363856]],
#
#        ...,
#
#        [[-0.9362959 , -0.810224  , -0.514684  ],
#         [-0.9362959 , -0.810224  , -0.514684  ],
#         [-0.9362959 , -0.810224  , -0.514684  ],
#         ...,
#         [-0.57667613, -0.44257697, -0.32296288],
#         [-0.55955136, -0.44257697, -0.30553368],
#         [-0.57667613, -0.460084  , -0.32296288]],
#
#        [[-0.95342064, -0.827731  , -0.5321132 ],
#         [-0.95342064, -0.827731  , -0.5321132 ],
#         [-0.9705454 , -0.84523803, -0.5321132 ],
#         ...,
#         [-0.6109256 , -0.495098  , -0.34039208],
#         [-0.59380084, -0.460084  , -0.32296288],
#         [-0.59380084, -0.495098  , -0.28810447]],
#
#        [[-0.95342064, -0.827731  , -0.5321132 ],
#         [-0.9705454 , -0.84523803, -0.5321132 ],
#         [-0.9705454 , -0.84523803, -0.5321132 ],
#         ...,
#         [-0.6109256 , -0.47759098, -0.32296288],
#         [-0.6109256 , -0.47759098, -0.34039208],
#         [-0.6280504 , -0.53011197, -0.28810447]]], dtype=float32)
